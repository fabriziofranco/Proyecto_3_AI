# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import utils

# %%
utils.plot_metrics("relu_4_capas_gd_senales_transito")

# %%
utils.compare_models(["relu_3_capas_gd_senales_transito","relu_4_capas_gd_senales_transito","relu_5_capas_gd_senales_transito"])
