# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import utils

# %% [markdown]
# ### Métricas de un modelo X

# %%
utils.plot_metrics("relu_3_capas_gd_senales_transito")

# %% [markdown]
# ### Comparación SGD vs GD

# %%
utils.compare_models(["relu_4_capas_sgd_senales_transito","relu_4_capas_gd_senales_transito"])

# %% [markdown]
# ### Comparación de datasets usando RELU

# %%
utils.compare_models(["relu_3_capas_gd_b_m","relu_3_capas_gd_senales_transito","relu_3_capas_gd_mariposas"])

# %% [markdown]
# ### Variación de número de capas para RELU

# %%
utils.compare_models(["relu_3_capas_gd_senales_transito","relu_4_capas_gd_senales_transito","relu_5_capas_gd_senales_transito"])

# %% [markdown]
# ### Comparación de Dataset Mariposas con y sin data augmentation

# %%
utils.compare_models(["relu_5_capas_gd_augmented_x5","relu_5_capas_gd_augmented_x10","relu_5_capas_gd_no_augmentation"])

# %% [markdown]
# ### Variación de número de capas para Tanh

# %%
utils.compare_models(["tanh_3_capas_gd_senales","tanh_4_capas_gd_senales"])

# %% [markdown]
# ### Variación número de capas Sigm

# %%
utils.compare_models(["sigm_1_capa_sgd_mariposas","sigm_1_capa_gd_mariposas","sigm_3_capas_gd_mariposas"])

# %% [markdown]
# ### TANH VS RELU VS SIGM PARA DATASET MARIPOSAS

# %%
utils.compare_models(["sigm_3_capas_gd_mariposas","tanh_3_capas_gd_mariposas","relu_3_capas_gd_mariposas"])

# %% [markdown]
# ### SIGM TUMORES VS SIGM SENALES DE TRANSITO

# %%
utils.compare_models(["sigm_3_capas_gd_b_m","sigm_3_capas_gd_senales"])

# %% [markdown]
# ### RELU VS TANH VS SIGM PARA SENALES DE TRANSITO

# %%
utils.compare_models(["sigm_3_capas_gd_senales","tanh_3_capas_gd_senales","relu_3_capas_gd_senales_transito"])
