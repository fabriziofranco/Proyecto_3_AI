# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/paolo/Desktop/Proyecto_3_AI/src/resultados/RESULTADOS.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/paolo/Desktop/Proyecto_3_AI/src/resultados/RESULTADOS.ipynb#ch0000000?line=0'>1</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/home/paolo/Desktop/Proyecto_3_AI/src/resultados/RESULTADOS.ipynb#ch0000000?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/home/paolo/Desktop/Proyecto_3_AI/src/resultados/RESULTADOS.ipynb#ch0000000?line=2'>3</a> import numpy as np
#       <a href='vscode-notebook-cell:/home/paolo/Desktop/Proyecto_3_AI/src/resultados/RESULTADOS.ipynb#ch0000000?line=3'>4</a> import utils
#
# ModuleNotFoundError: No module named 'pandas'

# %%
utils.plot_metrics("relu_5_capas_gd_mariposas_augmented")

# %%
utils.compare_models(["relu_3_capas_gd_senales_transito","relu_4_capas_gd_senales_transito","relu_5_capas_gd_senales_transito"])

# %%
utils.compare_models(["relu_5_capas_gd_mariposas_augmented","relu_5_capas_gd_mariposas_augmented_v2"])

# %%
utils.compare_models(["relu_5_capas_gd_mariposas_augmented","relu_5_capas_gd_mariposas_augmented_v2"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/paolo/Desktop/Proyecto_3_AI/src/resultados/RESULTADOS.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/paolo/Desktop/Proyecto_3_AI/src/resultados/RESULTADOS.ipynb#ch0000004?line=0'>1</a> utils.compare_models(["relu_5_capas_gd_mariposas_augmented","relu_5_capas_gd_mariposas_augmented_v2"])
#
# NameError: name 'utils' is not defined
